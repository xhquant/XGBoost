# %% [markdown]
# ## XGBoost模型参数

# %%
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import datasets
from sklearn.metrics import roc_auc_score

import xgboost as xgb

# %% [markdown]
# ### 二分类例子

# %%
print("二分类，乳腺癌数据")
cancer = datasets.load_breast_cancer()
X = cancer.data
y = cancer.target
# Out:
# 二分类，乳腺癌数据

# %%
kf = KFold(n_splits=5)
i = 0

# %%
for train_idx, test_idx in kf.split(X):
    x_train, x_test, y_train, y_test = X[train_idx], X[test_idx], y[train_idx], y[test_idx]
    model = xgb.XGBClassifier(max_depth=6,
                              max_leaves=50,
                              learning_rate=0.05,
                              n_estimators=60,
                              objective="binary:logistic",
                              booster="gbtree",
                              eval_metric="auc",
                              n_jobs=2,
                              early_stopping_rounds=20)
    model.fit(X=x_train,
              y=y_train, 
              eval_set=[(x_train, y_train), (x_test, y_test)])
    print(model)
    
    print("kfold-%d AUC为: %f" % (i, roc_auc_score(y_true=y_test, y_score=y_test)))
    i += 1
# Out:
# [0]	validation_0-auc:0.98811	validation_1-auc:0.90857
# [1]	validation_0-auc:0.99824	validation_1-auc:0.96340
# [2]	validation_0-auc:0.99808	validation_1-auc:0.96308
# [3]	validation_0-auc:0.99826	validation_1-auc:0.96340
# [4]	validation_0-auc:0.99837	validation_1-auc:0.96340
# [5]	validation_0-auc:0.99838	validation_1-auc:0.96276
# [6]	validation_0-auc:0.99829	validation_1-auc:0.96340
# [7]	validation_0-auc:0.99836	validation_1-auc:0.96340
# [8]	validation_0-auc:0.99904	validation_1-auc:0.97395
# [9]	validation_0-auc:0.99879	validation_1-auc:0.97426
# [10]	validation_0-auc:0.99884	validation_1-auc:0.97426
# [11]	validation_0-auc:0.99888	validation_1-auc:0.97363
# [12]	validation_0-auc:0.99911	validation_1-auc:0.97267
# [13]	validation_0-auc:0.99913	validation_1-auc:0.97331
# [14]	validation_0-auc:0.99902	validation_1-auc:0.97331
# [15]	validation_0-auc:0.99924	validation_1-auc:0.97267
# [16]	validation_0-auc:0.99915	validation_1-auc:0.97267
# [17]	validation_0-auc:0.99926	validation_1-auc:0.97522
# [18]	validation_0-auc:0.99931	validation_1-auc:0.97347
# [19]	validation_0-auc:0.99926	validation_1-auc:0.97347
# [20]	validation_0-auc:0.99922	validation_1-auc:0.97347
# [21]	validation_0-auc:0.99917	validation_1-auc:0.97538
# [22]	validation_0-auc:0.99944	validation_1-auc:0.97395
# [23]	validation_0-auc:0.99944	validation_1-auc:0.97474
# [24]	validation_0-auc:0.99935	validation_1-auc:0.97474
# [25]	validation_0-auc:0.99946	validation_1-auc:0.98098
# [26]	validation_0-auc:0.99944	validation_1-auc:0.98290
# [27]	validation_0-auc:0.99960	validation_1-auc:0.98194
# [28]	validation_0-auc:0.99958	validation_1-auc:0.98162
# [29]	validation_0-auc:0.99962	validation_1-auc:0.98082
# [30]	validation_0-auc:0.99962	validation_1-auc:0.98146
# [31]	validation_0-auc:0.99967	validation_1-auc:0.98354
# [32]	validation_0-auc:0.99967	validation_1-auc:0.98354
# [33]	validation_0-auc:0.99967	validation_1-auc:0.98370
# [34]	validation_0-auc:0.99967	validation_1-auc:0.98402
# [35]	validation_0-auc:0.99967	validation_1-auc:0.98370
# [36]	validation_0-auc:0.99967	validation_1-auc:0.98402
# [37]	validation_0-auc:0.99967	validation_1-auc:0.98402
# [38]	validation_0-auc:0.99969	validation_1-auc:0.98402
# [39]	validation_0-auc:0.99969	validation_1-auc:0.98402
# [40]	validation_0-auc:0.99969	validation_1-auc:0.98402
# [41]	validation_0-auc:0.99969	validation_1-auc:0.98402
# [42]	validation_0-auc:0.99969	validation_1-auc:0.98529
# [43]	validation_0-auc:0.99971	validation_1-auc:0.98465
# [44]	validation_0-auc:0.99971	validation_1-auc:0.98497
# [45]	validation_0-auc:0.99973	validation_1-auc:0.98497
# [46]	validation_0-auc:0.99973	validation_1-auc:0.98497
# [47]	validation_0-auc:0.99978	validation_1-auc:0.98497
# [48]	validation_0-auc:0.99978	validation_1-auc:0.98497
# [49]	validation_0-auc:0.99978	validation_1-auc:0.98497
# [50]	validation_0-auc:0.99978	validation_1-auc:0.98497
# [51]	validation_0-auc:0.99978	validation_1-auc:0.98529
# [52]	validation_0-auc:0.99978	validation_1-auc:0.98529
# [53]	validation_0-auc:0.99978	validation_1-auc:0.98465
# [54]	validation_0-auc:0.99978	validation_1-auc:0.98465
# [55]	validation_0-auc:0.99980	validation_1-auc:0.98465
# [56]	validation_0-auc:0.99984	validation_1-auc:0.98402
# [57]	validation_0-auc:0.99989	validation_1-auc:0.98434
# [58]	validation_0-auc:0.99989	validation_1-auc:0.98434
# [59]	validation_0-auc:0.99991	validation_1-auc:0.98434
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=20, enable_categorical=False,
#               eval_metric='auc', gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=50, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=60, n_jobs=2,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)
# kfold-0 AUC为: 1.000000
# [0]	validation_0-auc:0.99610	validation_1-auc:0.94819
# [1]	validation_0-auc:0.99881	validation_1-auc:0.94898
# [2]	validation_0-auc:0.99895	validation_1-auc:0.95542
# [3]	validation_0-auc:0.99889	validation_1-auc:0.95479
# [4]	validation_0-auc:0.99903	validation_1-auc:0.95495
# [5]	validation_0-auc:0.99891	validation_1-auc:0.95997
# [6]	validation_0-auc:0.99901	validation_1-auc:0.96060
# [7]	validation_0-auc:0.99920	validation_1-auc:0.96515
# [8]	validation_0-auc:0.99929	validation_1-auc:0.96641
# [9]	validation_0-auc:0.99933	validation_1-auc:0.96797
# [10]	validation_0-auc:0.99939	validation_1-auc:0.97457
# [11]	validation_0-auc:0.99947	validation_1-auc:0.97582
# [12]	validation_0-auc:0.99956	validation_1-auc:0.97645
# [13]	validation_0-auc:0.99960	validation_1-auc:0.97677
# [14]	validation_0-auc:0.99968	validation_1-auc:0.97677
# [15]	validation_0-auc:0.99971	validation_1-auc:0.97739
# [16]	validation_0-auc:0.99973	validation_1-auc:0.97771
# [17]	validation_0-auc:0.99973	validation_1-auc:0.97739
# [18]	validation_0-auc:0.99977	validation_1-auc:0.97677
# [19]	validation_0-auc:0.99992	validation_1-auc:0.97677
# [20]	validation_0-auc:0.99994	validation_1-auc:0.97661
# [21]	validation_0-auc:0.99994	validation_1-auc:0.97661
# [22]	validation_0-auc:0.99994	validation_1-auc:0.97724
# [23]	validation_0-auc:0.99996	validation_1-auc:0.97786
# [24]	validation_0-auc:0.99996	validation_1-auc:0.97786
# [25]	validation_0-auc:1.00000	validation_1-auc:0.97786
# [26]	validation_0-auc:1.00000	validation_1-auc:0.97786
# [27]	validation_0-auc:1.00000	validation_1-auc:0.97786
# [28]	validation_0-auc:1.00000	validation_1-auc:0.97786
# [29]	validation_0-auc:1.00000	validation_1-auc:0.97786
# [30]	validation_0-auc:1.00000	validation_1-auc:0.97912
# [31]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [32]	validation_0-auc:1.00000	validation_1-auc:0.97928
# [33]	validation_0-auc:1.00000	validation_1-auc:0.97928
# [34]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [35]	validation_0-auc:1.00000	validation_1-auc:0.97991
# [36]	validation_0-auc:1.00000	validation_1-auc:0.97991
# [37]	validation_0-auc:1.00000	validation_1-auc:0.97928
# [38]	validation_0-auc:1.00000	validation_1-auc:0.97928
# [39]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [40]	validation_0-auc:1.00000	validation_1-auc:0.97991
# [41]	validation_0-auc:1.00000	validation_1-auc:0.98053
# [42]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [43]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [44]	validation_0-auc:1.00000	validation_1-auc:0.97991
# [45]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [46]	validation_0-auc:1.00000	validation_1-auc:0.97991
# [47]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [48]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [49]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [50]	validation_0-auc:1.00000	validation_1-auc:0.97975
# [51]	validation_0-auc:1.00000	validation_1-auc:0.97975
# [52]	validation_0-auc:1.00000	validation_1-auc:0.97975
# [53]	validation_0-auc:1.00000	validation_1-auc:0.98006
# [54]	validation_0-auc:1.00000	validation_1-auc:0.98006
# [55]	validation_0-auc:1.00000	validation_1-auc:0.98006
# [56]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [57]	validation_0-auc:1.00000	validation_1-auc:0.97959
# [58]	validation_0-auc:1.00000	validation_1-auc:0.98524
# [59]	validation_0-auc:1.00000	validation_1-auc:0.98493
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=20, enable_categorical=False,
#               eval_metric='auc', gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=50, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=60, n_jobs=2,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)
# kfold-1 AUC为: 1.000000
# [0]	validation_0-auc:0.99307	validation_1-auc:0.97534
# [1]	validation_0-auc:0.99338	validation_1-auc:0.97517
# [2]	validation_0-auc:0.99727	validation_1-auc:0.97399
# [3]	validation_0-auc:0.99706	validation_1-auc:0.97551
# [4]	validation_0-auc:0.99799	validation_1-auc:0.97551
# [5]	validation_0-auc:0.99808	validation_1-auc:0.98615
# [6]	validation_0-auc:0.99842	validation_1-auc:0.98345
# [7]	validation_0-auc:0.99878	validation_1-auc:0.98345
# [8]	validation_0-auc:0.99874	validation_1-auc:0.98345
# [9]	validation_0-auc:0.99874	validation_1-auc:0.98598
# [10]	validation_0-auc:0.99874	validation_1-auc:0.98598
# [11]	validation_0-auc:0.99905	validation_1-auc:0.99122
# [12]	validation_0-auc:0.99899	validation_1-auc:0.99223
# [13]	validation_0-auc:0.99936	validation_1-auc:0.99257
# [14]	validation_0-auc:0.99936	validation_1-auc:0.99459
# [15]	validation_0-auc:0.99924	validation_1-auc:0.99426
# [16]	validation_0-auc:0.99951	validation_1-auc:0.99493
# [17]	validation_0-auc:0.99942	validation_1-auc:0.99459
# [18]	validation_0-auc:0.99951	validation_1-auc:0.99527
# [19]	validation_0-auc:0.99957	validation_1-auc:0.99527
# [20]	validation_0-auc:0.99967	validation_1-auc:0.99426
# [21]	validation_0-auc:0.99973	validation_1-auc:0.99426
# [22]	validation_0-auc:0.99973	validation_1-auc:0.99324
# [23]	validation_0-auc:0.99973	validation_1-auc:0.99324
# [24]	validation_0-auc:0.99973	validation_1-auc:0.99291
# [25]	validation_0-auc:0.99977	validation_1-auc:0.99291
# [26]	validation_0-auc:0.99986	validation_1-auc:0.99257
# [27]	validation_0-auc:0.99988	validation_1-auc:0.99257
# [28]	validation_0-auc:0.99988	validation_1-auc:0.99358
# [29]	validation_0-auc:0.99990	validation_1-auc:0.99358
# [30]	validation_0-auc:0.99992	validation_1-auc:0.99358
# [31]	validation_0-auc:0.99994	validation_1-auc:0.99358
# [32]	validation_0-auc:0.99994	validation_1-auc:0.99358
# [33]	validation_0-auc:0.99994	validation_1-auc:0.99324
# [34]	validation_0-auc:0.99994	validation_1-auc:0.99324
# [35]	validation_0-auc:0.99994	validation_1-auc:0.99291
# [36]	validation_0-auc:0.99994	validation_1-auc:0.99291
# [37]	validation_0-auc:0.99994	validation_1-auc:0.99257
# [38]	validation_0-auc:0.99994	validation_1-auc:0.99257
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=20, enable_categorical=False,
#               eval_metric='auc', gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=50, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=60, n_jobs=2,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)
# kfold-2 AUC为: 1.000000
# [0]	validation_0-auc:0.99296	validation_1-auc:0.97627
# [1]	validation_0-auc:0.99338	validation_1-auc:0.97667
# [2]	validation_0-auc:0.99310	validation_1-auc:0.97667
# [3]	validation_0-auc:0.99328	validation_1-auc:0.97708
# [4]	validation_0-auc:0.99324	validation_1-auc:0.97748
# [5]	validation_0-auc:0.99556	validation_1-auc:0.97769
# [6]	validation_0-auc:0.99569	validation_1-auc:0.97769
# [7]	validation_0-auc:0.99589	validation_1-auc:0.97748
# [8]	validation_0-auc:0.99587	validation_1-auc:0.97769
# [9]	validation_0-auc:0.99842	validation_1-auc:0.97688
# [10]	validation_0-auc:0.99848	validation_1-auc:0.97667
# [11]	validation_0-auc:0.99852	validation_1-auc:0.97667
# [12]	validation_0-auc:0.99864	validation_1-auc:0.97667
# [13]	validation_0-auc:0.99899	validation_1-auc:0.97708
# [14]	validation_0-auc:0.99899	validation_1-auc:0.97708
# [15]	validation_0-auc:0.99907	validation_1-auc:0.97748
# [16]	validation_0-auc:0.99909	validation_1-auc:0.97748
# [17]	validation_0-auc:0.99903	validation_1-auc:0.97748
# [18]	validation_0-auc:0.99901	validation_1-auc:0.97748
# [19]	validation_0-auc:0.99905	validation_1-auc:0.97748
# [20]	validation_0-auc:0.99903	validation_1-auc:0.97748
# [21]	validation_0-auc:0.99905	validation_1-auc:0.97748
# [22]	validation_0-auc:0.99903	validation_1-auc:0.97748
# [23]	validation_0-auc:0.99901	validation_1-auc:0.97748
# [24]	validation_0-auc:0.99916	validation_1-auc:0.99026
# [25]	validation_0-auc:0.99914	validation_1-auc:0.99351
# [26]	validation_0-auc:0.99916	validation_1-auc:0.99270
# [27]	validation_0-auc:0.99920	validation_1-auc:0.99310
# [28]	validation_0-auc:0.99920	validation_1-auc:0.99351
# [29]	validation_0-auc:0.99932	validation_1-auc:0.99351
# [30]	validation_0-auc:0.99932	validation_1-auc:0.99351
# [31]	validation_0-auc:0.99940	validation_1-auc:0.99351
# [32]	validation_0-auc:0.99936	validation_1-auc:0.99310
# [33]	validation_0-auc:0.99952	validation_1-auc:0.99270
# [34]	validation_0-auc:0.99960	validation_1-auc:0.99391
# [35]	validation_0-auc:0.99960	validation_1-auc:0.99513
# [36]	validation_0-auc:0.99960	validation_1-auc:0.99473
# [37]	validation_0-auc:0.99964	validation_1-auc:0.99473
# [38]	validation_0-auc:0.99966	validation_1-auc:0.99554
# [39]	validation_0-auc:0.99972	validation_1-auc:0.99554
# [40]	validation_0-auc:0.99974	validation_1-auc:0.99554
# [41]	validation_0-auc:0.99972	validation_1-auc:0.99554
# [42]	validation_0-auc:0.99972	validation_1-auc:0.99513
# [43]	validation_0-auc:0.99976	validation_1-auc:0.99513
# [44]	validation_0-auc:0.99974	validation_1-auc:0.99554
# [45]	validation_0-auc:0.99976	validation_1-auc:0.99594
# [46]	validation_0-auc:0.99976	validation_1-auc:0.99594
# [47]	validation_0-auc:0.99976	validation_1-auc:0.99554
# [48]	validation_0-auc:0.99984	validation_1-auc:0.99554
# [49]	validation_0-auc:0.99982	validation_1-auc:0.99554
# [50]	validation_0-auc:0.99984	validation_1-auc:0.99594
# [51]	validation_0-auc:0.99984	validation_1-auc:0.99554
# [52]	validation_0-auc:0.99986	validation_1-auc:0.99594
# [53]	validation_0-auc:0.99990	validation_1-auc:0.99554
# [54]	validation_0-auc:0.99992	validation_1-auc:0.99554
# [55]	validation_0-auc:0.99992	validation_1-auc:0.99554
# [56]	validation_0-auc:0.99992	validation_1-auc:0.99554
# [57]	validation_0-auc:0.99992	validation_1-auc:0.99554
# [58]	validation_0-auc:0.99992	validation_1-auc:0.99554
# [59]	validation_0-auc:0.99994	validation_1-auc:0.99554
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=20, enable_categorical=False,
#               eval_metric='auc', gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=50, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=60, n_jobs=2,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)
# kfold-3 AUC为: 1.000000
# [0]	validation_0-auc:0.99077	validation_1-auc:0.96729
# [1]	validation_0-auc:0.99085	validation_1-auc:0.97104
# [2]	validation_0-auc:0.99093	validation_1-auc:0.96972
# [3]	validation_0-auc:0.99841	validation_1-auc:0.98342
# [4]	validation_0-auc:0.99861	validation_1-auc:0.98386
# [5]	validation_0-auc:0.99886	validation_1-auc:0.98408
# [6]	validation_0-auc:0.99903	validation_1-auc:0.98453
# [7]	validation_0-auc:0.99903	validation_1-auc:0.98453
# [8]	validation_0-auc:0.99907	validation_1-auc:0.98453
# [9]	validation_0-auc:0.99911	validation_1-auc:0.98453
# [10]	validation_0-auc:0.99918	validation_1-auc:0.98453
# [11]	validation_0-auc:0.99940	validation_1-auc:0.98696
# [12]	validation_0-auc:0.99948	validation_1-auc:0.98784
# [13]	validation_0-auc:0.99960	validation_1-auc:0.98784
# [14]	validation_0-auc:0.99968	validation_1-auc:0.98784
# [15]	validation_0-auc:0.99970	validation_1-auc:0.99182
# [16]	validation_0-auc:0.99976	validation_1-auc:0.99182
# [17]	validation_0-auc:0.99976	validation_1-auc:0.99138
# [18]	validation_0-auc:0.99980	validation_1-auc:0.99094
# [19]	validation_0-auc:0.99982	validation_1-auc:0.99094
# [20]	validation_0-auc:0.99984	validation_1-auc:0.99337
# [21]	validation_0-auc:0.99982	validation_1-auc:0.99381
# [22]	validation_0-auc:0.99984	validation_1-auc:0.99381
# [23]	validation_0-auc:0.99988	validation_1-auc:0.99558
# [24]	validation_0-auc:0.99992	validation_1-auc:0.99602
# [25]	validation_0-auc:0.99992	validation_1-auc:0.99602
# [26]	validation_0-auc:0.99992	validation_1-auc:0.99602
# [27]	validation_0-auc:0.99992	validation_1-auc:0.99735
# [28]	validation_0-auc:0.99992	validation_1-auc:0.99735
# [29]	validation_0-auc:0.99992	validation_1-auc:0.99735
# [30]	validation_0-auc:0.99992	validation_1-auc:0.99735
# [31]	validation_0-auc:0.99992	validation_1-auc:0.99735
# [32]	validation_0-auc:0.99994	validation_1-auc:0.99779
# [33]	validation_0-auc:0.99996	validation_1-auc:0.99779
# [34]	validation_0-auc:0.99996	validation_1-auc:0.99779
# [35]	validation_0-auc:0.99996	validation_1-auc:0.99867
# [36]	validation_0-auc:0.99996	validation_1-auc:0.99823
# [37]	validation_0-auc:0.99996	validation_1-auc:0.99823
# [38]	validation_0-auc:0.99996	validation_1-auc:0.99823
# [39]	validation_0-auc:0.99996	validation_1-auc:0.99779
# [40]	validation_0-auc:1.00000	validation_1-auc:0.99779
# [41]	validation_0-auc:1.00000	validation_1-auc:0.99735
# [42]	validation_0-auc:0.99998	validation_1-auc:0.99735
# [43]	validation_0-auc:1.00000	validation_1-auc:0.99735
# [44]	validation_0-auc:1.00000	validation_1-auc:0.99735
# [45]	validation_0-auc:1.00000	validation_1-auc:0.99735
# [46]	validation_0-auc:1.00000	validation_1-auc:0.99779
# [47]	validation_0-auc:1.00000	validation_1-auc:0.99823
# [48]	validation_0-auc:1.00000	validation_1-auc:0.99823
# [49]	validation_0-auc:1.00000	validation_1-auc:0.99823
# [50]	validation_0-auc:1.00000	validation_1-auc:0.99823
# [51]	validation_0-auc:1.00000	validation_1-auc:0.99823
# [52]	validation_0-auc:1.00000	validation_1-auc:0.99823
# [53]	validation_0-auc:1.00000	validation_1-auc:0.99823
# [54]	validation_0-auc:1.00000	validation_1-auc:0.99823
# [55]	validation_0-auc:1.00000	validation_1-auc:0.99823
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=20, enable_categorical=False,
#               eval_metric='auc', gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=50, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=60, n_jobs=2,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)
# kfold-4 AUC为: 1.000000
